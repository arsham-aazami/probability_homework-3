# %%
import random
import matplotlib.pyplot as plt

def binomial_distribution(p, n):
    """Simulates the binomial distribution using relative frequency."""
    count = 0
    for i in range(n):
        if random.random() < p:
            count += 1
    return count

# Example usage
p = 0.9
n = 500
results = [binomial_distribution(p, n) for _ in range(10000)]
relative_frequency = sum(results) / (n * len(results))

# Plot the PMF
x = range(1, n + 1)
pmf = [results.count(i) / len(results) for i in x]
mean = n*p 
plt.stem(x, pmf, use_line_collection=True)
plt.title(f"Binomial Distribution PMF with p={p} and n={n}")
plt.xlabel("Number of trials needed to get the first success")
plt.ylabel("Probability")
plt.show()
print(f"The Expected value of random variable X is {mean}")
# Out:
# C:\Users\arsha\AppData\Local\Temp\ipykernel_4416\2379837906.py:22: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(x, pmf, use_line_collection=True)
# The Expected value of random variable X is 450.0

# %%
import random
import matplotlib.pyplot as plt
from collections import Counter

def geometric_distribution(p, num_simulations):
    """simulate a geometric distribution"""
    results = []
    for _ in range(num_simulations):
        trials_until_success = 1
        while random.random() > p:
            trials_until_success += 1
        results.append(trials_until_success)
    return results

def plot_geometric_pmf(results):
    counts = Counter(results)
    max_trials = max(results)

    plt.stem(counts.keys(), [count / len(results) for count in counts.values()], use_line_collection=True)
    plt.title('Geometric Distribution PMF (Simulation)')
    plt.xlabel('Number of Trials until Success')
    plt.ylabel('Probability')
    plt.xticks(range(1, max_trials + 1))
    plt.show()

n = 50
p = 0.7
mean = 1/p
results = geometric_distribution(p, n)
plot_geometric_pmf(results)
print(mean)
# Out:
# C:\Users\arsha\AppData\Local\Temp\ipykernel_4416\3548606366.py:19: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(counts.keys(), [count / len(results) for count in counts.values()], use_line_collection=True)
# 1.4285714285714286

# %%
print(binomial_distribution(0.7, 50))
results = [binomial_distribution(p, n) for _ in range(10000)]
print(results)
print(len(results))
relative_frequency = sum(results) / (n * len(results))
print(relative_frequency)
# Out:
# 36
# [39, 34, 40, 39, 38, 33, 37, 40, 33, 36, 33, 28, 38, 33, 38, 36, 32, 35, 38, 36, 32, 35, 34, 33, 39, 29, 32, 32, 39, 38, 33, 37, 33, 32, 35, 34, 31, 34, 38, 29, 27, 39, 33, 34, 37, 39, 33, 37, 33, 36, 32, 41, 35, 30, 35, 28, 31, 32, 35, 36, 36, 29, 36, 36, 39, 39, 30, 37, 38, 32, 36, 34, 40, 36, 34, 34, 37, 31, 33, 34, 37, 35, 30, 34, 34, 38, 39, 28, 31, 36, 37, 29, 42, 35, 40, 34, 36, 39, 36, 29, 36, 34, 33, 33, 32, 37, 32, 31, 34, 28, 39, 40, 34, 33, 35, 35, 31, 34, 34, 33, 29, 35, 38, 36, 39, 33, 39, 26, 37, 37, 39, 36, 34, 37, 31, 30, 35, 37, 36, 31, 41, 30, 35, 38, 39, 30, 35, 38, 36, 33, 36, 37, 35, 34, 35, 37, 34, 36, 34, 36, 37, 35, 34, 37, 39, 36, 36, 37, 40, 34, 35, 34, 35, 32, 33, 32, 35, 30, 34, 36, 31, 35, 30, 38, 36, 30, 39, 32, 32, 34, 37, 36, 33, 36, 37, 39, 38, 36, 36, 35, 35, 34, 34, 41, 36, 34, 36, 31, 30, 34, 35, 40, 32, 34, 39, 32, 31, 36, 37,
35, 40, 42, 35, 34, 36, 36, 28, 34, 34, 28, 30, 30, 37, 35, 34, 38, 37, 37, 36, 32, 33, 30, 36, 28, 39, 31, 38, 35, 35, 33, 41, 33, 35, 37, 28, 33, 39, 33, 33, 33, 39, 43, 33, 34, 40, 35, 33, 35, 34, 27, 34, 36, 27, 38, 39, 35, 33, 32, 35, 34, 34, 38, 37, 36, 31, 37, 31, 37, 37, 37, 37, 35, 35, 30, 37, 28, 31, 35, 36, 40, 37, 34, 33, 34, 33, 38, 31, 30, 37, 37, 36, 38, 30, 29, 40, 32, 33, 36, 37, 36, 32, 31, 37, 27, 33, 38, 40, 36, 35, 34, 33, 32, 38, 34, 40, 33, 28, 39, 36, 38, 33, 42, 26, 33, 36, 35, 26, 33, 38, 39, 32, 34, 34, 26, 39, 35, 35, 30, 34, 32, 31, 38, 39, 35, 38, 29, 36, 33, 36, 38, 36, 38, 38, 38, 36, 33, 43, 37, 31, 39, 32, 31, 40, 34, 33, 38, 34, 30, 39, 33, 34, 39, 31, 36, 37, 35, 32, 38, 34, 34, 43, 40, 26, 33, 36, 33, 36, 34, 31, 37, 36, 37, 33, 33, 37, 40, 36, 36, 35, 36, 39, 31, 39, 34, 33, 28, 32, 35, 40, 37, 30, 33, 36, 36, 32, 35, 31, 32, 34, 34, 35, 30, 39, 33, 36, 38, 32, 35, 36, 32, 39, 34, 38, 38, 40, 37, 28, 36, 34, 33, 36, 37, 35, 37, 33, 34, 31, ...
# 10000
# 0.70007

# %%
calculate_bionmial_pmf_and_mean(500, 0.7)
# Out:
# mean of the random variable X = 349.9999999999997

# %%
calculate_bionmial_pmf_and_mean(50, 0.9)
# Out:
# mean of the random variable X = 45.0

# %%
calculate_bionmial_pmf_and_mean(500, 0.9)
# Out:
# mean of the random variable X = 450.00000000000017

# %%
import matplotlib.pyplot as plt

def calculate_geometric_pmf_and_mean(n, p):
    # S(Y) = {1, 2, 3, ...}
    # Create a list of possible outcomes and their probabilities
    probailities = [(1 - p)**(k - 1) * p for k in range(1, n + 1)]
    # Calculate the expected value of the random variable X
    mean = 1 / p
    # Plot the probability mass function
    fig, ax = plt.subplots(figsize=(10, 5))
    ax.stem(range(1, n + 1), probailities)
    
    plt.xlabel(f"Y ~ Geometric(n={n}, p={p})")
    plt.ylabel("pmf")
    plt.title("Geometric Probability Mass Function")
    plt.show()
    
    print(f"mean of the random variable Y = {mean}")

# %%
calculate_geometric_pmf_and_mean(50, 0.7)
# Out:
# mean of the random variable Y = 1.4285714285714286

# %%
import random
import matplotlib.pyplot as plt

def binomial_distribution(p, n):
    """Simulates the geometric distribution using relative frequency."""
    count = 0
    for i in range(n):
        if random.random() < p:
            count += 1
    return count

# Example usage
p = 0.7
n = 50
results = [binomial_distribution(p, n) for _ in range(10000)]
relative_frequency = sum(results) / (n * len(results))

# Plot the PMF
x = range(1, n + 1)
pmf = [results.count(i) / len(results) for i in x]
plt.stem(x, pmf, use_line_collection=True)
plt.title(f"Geometric Distribution PMF with p={p} and n={n}")
plt.xlabel("Number of trials needed to get the first success")
plt.ylabel("Probability")
plt.show()
# Out:
# C:\Users\arsha\AppData\Local\Temp\ipykernel_12124\3496251832.py:21: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(x, pmf, use_line_collection=True)
